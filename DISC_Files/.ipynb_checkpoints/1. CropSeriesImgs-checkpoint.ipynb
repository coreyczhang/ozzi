# %%
import cv2
import os
from tqdm import tqdm

window_width = 600
window_height = 1200

def draw_box(image):
    # Display the image and allow the user to draw a box
    clone = image.copy()
    cv2.namedWindow("Draw Box", cv2.WINDOW_NORMAL)
    cv2.resizeWindow("Draw Box", window_width, window_height)

    # Initialize variables for the box coordinates
    box_start = None
    box_end = None
    drawing = False
    last_update_time = 0
    update_interval = 0.02  # Update every 20 milliseconds

    def draw_rectangle(event, x, y, flags, param):
        nonlocal box_start, box_end, drawing, clone, last_update_time

        # Handle mouse events
        if event == cv2.EVENT_LBUTTONDOWN:
            box_start = (x, y)
            drawing = True

        elif event == cv2.EVENT_MOUSEMOVE:
            if drawing:
                current_time = time.time()
                if current_time - last_update_time > update_interval:
                    last_update_time = current_time
                    clone = image.copy()
                    cv2.rectangle(clone, box_start, (x, y), (0, 255, 0), 2)
                    cv2.imshow("Draw Box", clone)

        elif event == cv2.EVENT_LBUTTONUP:
            box_end = (x, y)
            drawing = False
            cv2.rectangle(clone, box_start, box_end, (0, 255, 0), 2)
            cv2.imshow("Draw Box", clone)

    # Register the callback function for mouse events
    cv2.setMouseCallback("Draw Box", draw_rectangle)

    cv2.imshow("Draw Box", clone)

    # Wait for the user to draw the box and close the window
    while True:
        key = cv2.waitKey(1) & 0xFF

        if key == ord("r"):
            # Reset the box if the 'r' key is pressed
            clone = image.copy()
            cv2.imshow("Draw Box", clone)

        elif key == ord("c"):
            # Close the window and proceed to crop the images if the 'c' key is pressed
            break

    cv2.destroyAllWindows()

    # Return the box coordinates
    return box_start, box_end

def crop_and_save_images(inDir, box_start, box_end, image_files):
    # Crop each image and save it
    outDir = os.path.join(inDir, 'Cropped')
    os.makedirs(outDir, exist_ok=True)
    print("Cropping process initiated...")
    for i, image_file in enumerate(tqdm(image_files, desc="Processing images", unit="file")):
        image_path = os.path.join(inDir, image_file)
        image = cv2.imread(image_path)
        if image is None:
            print(f"Error loading image: {image_path}")
            continue
        cropped_image = image[box_start[1]:box_end[1], box_start[0]:box_end[0]]
        cv2.imwrite(os.path.join(outDir, f"cropped_{image_file}"), cropped_image)
    print(f"Total frames processed: {len(image_files)}")

# Directory containing the images
inDir = r"/Users/eugene/Documents/Mice_Output"  # Replace with the actual directory path

# Get a list of image file names in the directory
image_files = [f for f in os.listdir(inDir) if f.endswith('.png')]

# Ensure there are images to process
if not image_files:
    raise Exception(f"No PNG images found in directory: {inDir}")

# Load only the first image
first_image = cv2.imread(os.path.join(inDir, image_files[0]))
if first_image is None:
    raise Exception(f"Error loading the first image: {os.path.join(inDir, image_files[0])}")

# Draw a box on the first image
box_start, box_end = draw_box(first_image)

# Crop and save the series of images
crop_and_save_images(inDir, box_start, box_end, image_files)

print("Cropping process completed.")
# Out:
# 2024-07-23 12:28:07.942 Python[45950:34648972] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
# Cropping process initiated...
# Processing images:   0%|                       | 1/1102 [00:00<02:52,  6.40it/s]
# Cropped and saved 1/1102 images
# Processing images:   0%|                       | 2/1102 [00:00<02:51,  6.41it/s]
# Cropped and saved 2/1102 images
# Processing images:   0%|                       | 3/1102 [00:00<02:53,  6.34it/s]
# Cropped and saved 3/1102 images
# Processing images:   0%|                       | 4/1102 [00:00<02:46,  6.59it/s]
# Cropped and saved 4/1102 images
# Processing images:   0%|                       | 5/1102 [00:00<02:43,  6.72it/s]
# Cropped and saved 5/1102 images
# Processing images:   1%|▏                      | 6/1102 [00:00<02:44,  6.64it/s]
# Cropped and saved 6/1102 images
# Processing images:   1%|▏                      | 7/1102 [00:01<02:42,  6.73it/s]
# Cropped and saved 7/1102 images
# Processing images:   1%|▏                      | 8/1102 [00:01<02:43,  6.70it/s]
# Cropped and saved 8/1102 images
# Processing images:   1%|▏                      | 9/1102 [00:01<02:42,  6.73it/s]
# Cropped and saved 9/1102 images
# Processing images:   1%|▏                     | 10/1102 [00:01<02:43,  6.67it/s]
# Cropped and saved 10/1102 images
# Processing images:   1%|▏                     | 11/1102 [00:01<02:43,  6.66it/s]
# Cropped and saved 11/1102 images
# Processing images:   1%|▏                     | 12/1102 [00:01<02:42,  6.70it/s]
# Cropped and saved 12/1102 images
# Processing images:   1%|▎                     | 13/1102 [00:01<02:42,  6.71it/s]
# Cropped and saved 13/1102 images
# Processing images:   1%|▎                     | 14/1102 [00:02<02:44,  6.63it/s]
# Cropped and saved 14/1102 images
# Processing images:   1%|▎                     | 15/1102 [00:02<02:44,  6.59it/s]
# Cropped and saved 15/1102 images
# Processing images:   1%|▎                     | 16/1102 [00:02<02:42,  6.69it/s]
# Cropped and saved 16/1102 images
# Processing images:   2%|▎                     | 17/1102 [00:02<02:40,  6.75it/s]
# Cropped and saved 17/1102 images
# Processing images:   2%|▎                     | 18/1102 [00:02<02:41,  6.73it/s]
# Cropped and saved 18/1102 images
# Processing images:   2%|▍                     | 19/1102 [00:02<02:40,  6.75it/s]
# Cropped and saved 19/1102 images
# Processing images:   2%|▍                     | 20/1102 [00:02<02:41,  6.70it/s]
# Cropped and saved 20/1102 images
# Processing images:   2%|▍                     | 21/1102 [00:03<02:40,  6.72it/s]
# Cropped and saved 21/1102 images
# Processing images:   2%|▍                     | 22/1102 [00:03<02:41,  6.71it/s]
# Cropped and saved 22/1102 images
# Processing images:   2%|▍                     | 23/1102 [00:03<02:43,  6.61it/s]
# Cropped and saved 23/1102 images
# Processing images:   2%|▍                     | 24/1102 [00:03<02:40,  6.71it/s]
# Cropped and saved 24/1102 images
# Processing images:   2%|▍                     | 25/1102 [00:03<02:39,  6.73it/s]
# Cropped and saved 25/1102 images
# Processing images:   2%|▌                     | 26/1102 [00:03<02:39,  6.75it/s]
# Cropped and saved 26/1102 images
# Processing images:   2%|▌                     | 27/1102 [00:04<02:40,  6.71it/s]
# Cropped and saved 27/1102 images
# Processing images:   3%|▌                     | 28/1102 [00:04<02:38,  6.76it/s]
# Cropped and saved 28/1102 images
# Processing images:   3%|▌                     | 29/1102 [00:04<02:39,  6.74it/s]
# Cropped and saved 29/1102 images
# Processing images:   3%|▌                     | 30/1102 [00:04<02:36,  6.83it/s]
# Cropped and saved 30/1102 images
# Processing images:   3%|▌                     | 31/1102 [00:04<02:36,  6.83it/s]
# Cropped and saved 31/1102 images
# Processing images:   3%|▋                     | 32/1102 [00:04<02:35,  6.89it/s]
# Cropped and saved 32/1102 images
# Processing images:   3%|▋                     | 33/1102 [00:04<02:38,  6.72it/s]
# Cropped and saved 33/1102 images
# Processing images:   3%|▋                     | 34/1102 [00:05<02:38,  6.73it/s]
# Cropped and saved 34/1102 images
# Processing images:   3%|▋                     | 35/1102 [00:05<02:37,  6.76it/s]
# Cropped and saved 35/1102 images
# Processing images:   3%|▋                     | 36/1102 [00:05<02:36,  6.80it/s]
# Cropped and saved 36/1102 images
# Processing images:   3%|▋                     | 37/1102 [00:05<02:37,  6.77it/s]
# Cropped and saved 37/1102 images
# Processing images:   3%|▊                     | 38/1102 [00:05<02:37,  6.77it/s]
# Cropped and saved 38/1102 images
# Processing images:   4%|▊                     | 39/1102 [00:05<02:36,  6.80it/s]
# Cropped and saved 39/1102 images
# Processing images:   4%|▊                     | 40/1102 [00:05<02:35,  6.81it/s]
# Cropped and saved 40/1102 images
# Processing images:   4%|▊                     | 41/1102 [00:06<02:38,  6.67it/s]
# Cropped and saved 41/1102 images
# Processing images:   4%|▊                     | 42/1102 [00:06<02:37,  6.71it/s]
# Cropped and saved 42/1102 images
# Processing images:   4%|▊                     | 43/1102 [00:06<02:40,  6.59it/s]
# Cropped and saved 43/1102 images
# Processing images:   4%|▉                     | 44/1102 [00:06<02:37,  6.70it/s]
# Cropped and saved 44/1102 images
# Processing images:   4%|▉                     | 45/1102 [00:06<02:36,  6.75it/s]
# Cropped and saved 45/1102 images
# Processing images:   4%|▉                     | 46/1102 [00:06<02:37,  6.70it/s]
# Cropped and saved 46/1102 images
# Processing images:   4%|▉                     | 47/1102 [00:07<02:35,  6.78it/s]
# Cropped and saved 47/1102 images
# Processing images:   4%|▉                     | 48/1102 [00:07<02:37,  6.69it/s]
# Cropped and saved 48/1102 images
# Processing images:   4%|▉                     | 49/1102 [00:07<02:36,  6.72it/s]
# Cropped and saved 49/1102 images
# Processing images:   5%|▉                     | 50/1102 [00:07<02:37,  6.70it/s]
# Cropped and saved 50/1102 images
# Processing images:   5%|█                     | 51/1102 [00:07<02:36,  6.73it/s]
# Cropped and saved 51/1102 images
# Processing images:   5%|█                     | 52/1102 [00:07<02:34,  6.78it/s]
# Cropped and saved 52/1102 images
# Processing images:   5%|█                     | 53/1102 [00:07<02:34,  6.79it/s]
# Cropped and saved 53/1102 images
# Processing images:   5%|█                     | 54/1102 [00:08<02:34,  6.79it/s]
# Cropped and saved 54/1102 images
# Processing images:   5%|█                     | 55/1102 [00:08<02:40,  6.54it/s]
# Cropped and saved 55/1102 images
# Processing images:   5%|█                     | 56/1102 [00:08<02:39,  6.54it/s]
# Cropped and saved 56/1102 images
# Processing images:   5%|█▏                    | 57/1102 [00:08<02:38,  6.60it/s]
# Cropped and saved 57/1102 images
# Processing images:   5%|█▏                    | 58/1102 [00:08<02:36,  6.67it/s]
# Cropped and saved 58/1102 images
# Processing images:   5%|█▏                    | 59/1102 [00:08<02:34,  6.77it/s]
# Cropped and saved 59/1102 images
# Processing images:   5%|█▏                    | 60/1102 [00:08<02:36,  6.68it/s]
# Cropped and saved 60/1102 images
# Processing images:   6%|█▏                    | 61/1102 [00:09<02:34,  6.76it/s]
# Cropped and saved 61/1102 images
# Processing images:   6%|█▏                    | 62/1102 [00:09<02:33,  6.78it/s]
# Cropped and saved 62/1102 images
# Processing images:   6%|█▎                    | 63/1102 [00:09<02:32,  6.83it/s]
# Cropped and saved 63/1102 images
# Processing images:   6%|█▎                    | 64/1102 [00:09<02:32,  6.81it/s]
# Cropped and saved 64/1102 images
# Processing images:   6%|█▎                    | 65/1102 [00:09<02:31,  6.85it/s]
# Cropped and saved 65/1102 images
# Processing images:   6%|█▎                    | 66/1102 [00:09<02:33,  6.75it/s]
# Cropped and saved 66/1102 images
# Processing images:   6%|█▎                    | 67/1102 [00:09<02:32,  6.78it/s]
# Cropped and saved 67/1102 images
# Processing images:   6%|█▎                    | 68/1102 [00:10<02:34,  6.69it/s]
# Cropped and saved 68/1102 images
# Processing images:   6%|█▍                    | 69/1102 [00:10<02:34,  6.70it/s]
# Cropped and saved 69/1102 images
# Processing images:   6%|█▍                    | 70/1102 [00:10<02:31,  6.81it/s]
# Cropped and saved 70/1102 images
# Processing images:   6%|█▍                    | 71/1102 [00:10<02:30,  6.85it/s]
# Cropped and saved 71/1102 images
# Processing images:   7%|█▍                    | 72/1102 [00:10<02:29,  6.87it/s]
# Cropped and saved 72/1102 images
# Processing images:   7%|█▍                    | 73/1102 [00:10<02:29,  6.88it/s]
# Cropped and saved 73/1102 images
# Processing images:   7%|█▍                    | 74/1102 [00:10<02:29,  6.88it/s]
# Cropped and saved 74/1102 images
# Processing images:   7%|█▍                    | 75/1102 [00:11<02:30,  6.82it/s]
# Cropped and saved 75/1102 images
# Processing images:   7%|█▌                    | 76/1102 [00:11<02:28,  6.89it/s]
# Cropped and saved 76/1102 images
# Processing images:   7%|█▌                    | 77/1102 [00:11<02:28,  6.92it/s]
# Cropped and saved 77/1102 images
# Processing images:   7%|█▌                    | 78/1102 [00:11<02:27,  6.94it/s]
# Cropped and saved 78/1102 images
# Processing images:   7%|█▌                    | 79/1102 [00:11<02:28,  6.89it/s]
# Cropped and saved 79/1102 images
# Processing images:   7%|█▌                    | 80/1102 [00:11<02:30,  6.81it/s]
# Cropped and saved 80/1102 images
# Processing images:   7%|█▌                    | 81/1102 [00:12<02:30,  6.79it/s]
# Cropped and saved 81/1102 images
# Processing images:   7%|█▋                    | 82/1102 [00:12<02:29,  6.83it/s]
# Cropped and saved 82/1102 images
# Processing images:   8%|█▋                    | 83/1102 [00:12<02:29,  6.82it/s]
# Cropped and saved 83/1102 images
# Processing images:   8%|█▋                    | 84/1102 [00:12<02:28,  6.86it/s]
# Cropped and saved 84/1102 images
# Processing images:   8%|█▋                    | 85/1102 [00:12<02:27,  6.90it/s]
# Cropped and saved 85/1102 images
# Processing images:   8%|█▋                    | 86/1102 [00:12<02:26,  6.95it/s]
# Cropped and saved 86/1102 images
# Processing images:   8%|█▋                    | 87/1102 [00:12<02:26,  6.94it/s]
# Cropped and saved 87/1102 images
# Processing images:   8%|█▊                    | 88/1102 [00:13<02:26,  6.91it/s]
# Cropped and saved 88/1102 images
# Processing images:   8%|█▊                    | 89/1102 [00:13<02:25,  6.95it/s]
# Cropped and saved 89/1102 images
# Processing images:   8%|█▊                    | 90/1102 [00:13<02:25,  6.94it/s]
# Cropped and saved 90/1102 images
# Processing images:   8%|█▊                    | 91/1102 [00:13<02:26,  6.92it/s]
# Cropped and saved 91/1102 images
# Processing images:   8%|█▊                    | 92/1102 [00:13<02:26,  6.90it/s]
# Cropped and saved 92/1102 images
# Processing images:   8%|█▊                    | 93/1102 [00:13<02:25,  6.94it/s]
# Cropped and saved 93/1102 images
# Processing images:   9%|█▉                    | 94/1102 [00:13<02:25,  6.93it/s]
# Cropped and saved 94/1102 images
# Processing images:   9%|█▉                    | 95/1102 [00:14<02:24,  6.97it/s]
# Cropped and saved 95/1102 images
# Processing images:   9%|█▉                    | 96/1102 [00:14<02:24,  6.98it/s]
# Cropped and saved 96/1102 images
# Processing images:   9%|█▉                    | 97/1102 [00:14<02:24,  6.96it/s]
# Cropped and saved 97/1102 images
# Processing images:   9%|█▉                    | 98/1102 [00:14<02:23,  6.97it/s]
# Cropped and saved 98/1102 images
# Processing images:   9%|█▉                    | 99/1102 [00:14<02:24,  6.96it/s]
# Cropped and saved 99/1102 images
# Processing images:   9%|█▉                   | 100/1102 [00:14<02:23,  6.98it/s]
# Cropped and saved 100/1102 images
# Processing images:   9%|█▉                   | 101/1102 [00:14<02:23,  6.99it/s]
# Cropped and saved 101/1102 images
# Processing images:   9%|█▉                   | 102/1102 [00:15<02:23,  6.98it/s]
# Cropped and saved 102/1102 images
# Processing images:   9%|█▉                   | 103/1102 [00:15<02:22,  7.00it/s]
# Cropped and saved 103/1102 images
# Processing images:   9%|█▉                   | 104/1102 [00:15<02:23,  6.98it/s]
# Cropped and saved 104/1102 images
# Processing images:  10%|██                   | 105/1102 [00:15<02:23,  6.97it/s]
# Cropped and saved 105/1102 images
# Processing images:  10%|██                   | 106/1102 [00:15<02:22,  6.97it/s]
# Cropped and saved 106/1102 images
# Processing images:  10%|██                   | 107/1102 [00:15<02:22,  6.96it/s]
# Cropped and saved 107/1102 images
# Processing images:  10%|██                   | 108/1102 [00:15<02:22,  6.95it/s]
# Cropped and saved 108/1102 images
# Processing images:  10%|██                   | 109/1102 [00:16<02:22,  6.96it/s]
# Cropped and saved 109/1102 images
# Processing images:  10%|██                   | 110/1102 [00:16<02:22,  6.95it/s]
# Cropped and saved 110/1102 images
# Processing images:  10%|██                   | 111/1102 [00:16<02:22,  6.94it/s]
# Cropped and saved 111/1102 images
# Processing images:  10%|██▏                  | 112/1102 [00:16<02:22,  6.94it/s]
# Cropped and saved 112/1102 images
# Processing images:  10%|██▏                  | 113/1102 [00:16<02:22,  6.92it/s]
# Cropped and saved 113/1102 images
# Processing images:  10%|██▏                  | 114/1102 [00:16<02:22,  6.91it/s]
# Cropped and saved 114/1102 images
# Processing images:  10%|██▏                  | 115/1102 [00:16<02:22,  6.90it/s]
# Cropped and saved 115/1102 images
# Processing images:  11%|██▏                  | 116/1102 [00:17<02:22,  6.90it/s]
# Cropped and saved 116/1102 images
# Processing images:  11%|██▏                  | 117/1102 [00:17<02:21,  6.96it/s]
# Cropped and saved 117/1102 images
# Processing images:  11%|██▏                  | 118/1102 [00:17<02:20,  6.98it/s]
# Cropped and saved 118/1102 images
# Processing images:  11%|██▎                  | 119/1102 [00:17<02:21,  6.97it/s]
# Cropped and saved 119/1102 images
# Processing images:  11%|██▎                  | 120/1102 [00:17<02:21,  6.95it/s]
# Cropped and saved 120/1102 images
# Processing images:  11%|██▎                  | 121/1102 [00:17<02:22,  6.90it/s]
# Cropped and saved 121/1102 images
# Processing images:  11%|██▎                  | 122/1102 [00:17<02:21,  6.92it/s]
# Cropped and saved 122/1102 images
# Processing images:  11%|██▎                  | 123/1102 [00:18<02:21,  6.94it/s]
# Cropped and saved 123/1102 images
# Processing images:  11%|██▎                  | 124/1102 [00:18<02:21,  6.93it/s]
# Cropped and saved 124/1102 images
# Processing images:  11%|██▍                  | 125/1102 [00:18<02:20,  6.95it/s]
# Cropped and saved 125/1102 images
# Processing images:  11%|██▍                  | 126/1102 [00:18<02:19,  6.98it/s]
# Cropped and saved 126/1102 images
# Processing images:  12%|██▍                  | 127/1102 [00:18<02:20,  6.96it/s]
# Cropped and saved 127/1102 images
# Processing images:  12%|██▍                  | 128/1102 [00:18<02:20,  6.93it/s]
# Cropped and saved 128/1102 images
# Processing images:  12%|██▍                  | 129/1102 [00:18<02:19,  6.96it/s]
# Cropped and saved 129/1102 images
# Processing images:  12%|██▍                  | 130/1102 [00:19<02:19,  6.95it/s]
# Cropped and saved 130/1102 images
# Processing images:  12%|██▍                  | 131/1102 [00:19<02:19,  6.95it/s]
# Cropped and saved 131/1102 images
# Processing images:  12%|██▌                  | 132/1102 [00:19<02:19,  6.95it/s]
# Cropped and saved 132/1102 images
# Processing images:  12%|██▌                  | 133/1102 [00:19<02:18,  7.01it/s]
# Cropped and saved 133/1102 images
# Processing images:  12%|██▌                  | 134/1102 [00:19<02:18,  6.97it/s]
# Cropped and saved 134/1102 images
# Processing images:  12%|██▌                  | 135/1102 [00:19<02:18,  6.98it/s]
# Cropped and saved 135/1102 images
# Processing images:  12%|██▌                  | 136/1102 [00:19<02:19,  6.95it/s]
# Cropped and saved 136/1102 images
# Processing images:  12%|██▌                  | 137/1102 [00:20<02:18,  6.97it/s]
# Cropped and saved 137/1102 images
# Processing images:  13%|██▋                  | 138/1102 [00:20<02:18,  6.96it/s]
# Cropped and saved 138/1102 images
# Processing images:  13%|██▋                  | 139/1102 [00:20<02:20,  6.85it/s]
# Cropped and saved 139/1102 images
# Processing images:  13%|██▋                  | 140/1102 [00:20<02:19,  6.89it/s]
# Cropped and saved 140/1102 images
# Processing images:  13%|██▋                  | 141/1102 [00:20<02:18,  6.93it/s]
# Cropped and saved 141/1102 images
# Processing images:  13%|██▋                  | 142/1102 [00:20<02:19,  6.90it/s]
# Cropped and saved 142/1102 images
# Processing images:  13%|██▋                  | 143/1102 [00:20<02:18,  6.94it/s]
# Cropped and saved 143/1102 images
# Processing images:  13%|██▋                  | 144/1102 [00:21<02:18,  6.92it/s]
# Cropped and saved 144/1102 images
# Processing images:  13%|██▊                  | 145/1102 [00:21<02:17,  6.97it/s]
# Cropped and saved 145/1102 images
# Processing images:  13%|██▊                  | 146/1102 [00:21<02:18,  6.91it/s]
# Cropped and saved 146/1102 images
# Processing images:  13%|██▊                  | 147/1102 [00:21<02:18,  6.91it/s]
# Cropped and saved 147/1102 images
# Processing images:  13%|██▊                  | 148/1102 [00:21<02:17,  6.93it/s]
# Cropped and saved 148/1102 images
# Processing images:  14%|██▊                  | 149/1102 [00:21<02:17,  6.93it/s]
# Cropped and saved 149/1102 images
# Processing images:  14%|██▊                  | 150/1102 [00:21<02:17,  6.92it/s]
# Cropped and saved 150/1102 images
# Processing images:  14%|██▉                  | 151/1102 [00:22<02:17,  6.92it/s]
# Cropped and saved 151/1102 images
# Processing images:  14%|██▉                  | 152/1102 [00:22<02:16,  6.94it/s]
# Cropped and saved 152/1102 images
# Processing images:  14%|██▉                  | 153/1102 [00:22<02:16,  6.94it/s]
# Cropped and saved 153/1102 images
# Processing images:  14%|██▉                  | 154/1102 [00:22<02:16,  6.96it/s]
# Cropped and saved 154/1102 images
# Processing images:  14%|██▉                  | 155/1102 [00:22<02:16,  6.95it/s]
# Cropped and saved 155/1102 images
# Processing images:  14%|██▉                  | 156/1102 [00:22<02:15,  6.96it/s]
# Cropped and saved 156/1102 images
# Processing images:  14%|██▉                  | 157/1102 [00:22<02:15,  6.96it/s]
# Cropped and saved 157/1102 images
# Processing images:  14%|███                  | 158/1102 [00:23<02:15,  6.96it/s]
# Cropped and saved 158/1102 images
# Processing images:  14%|███                  | 159/1102 [00:23<02:15,  6.97it/s]
# Cropped and saved 159/1102 images
# Processing images:  15%|███                  | 160/1102 [00:23<02:14,  6.98it/s]
# Cropped and saved 160/1102 images
# Processing images:  15%|███                  | 161/1102 [00:23<02:15,  6.97it/s]
# Cropped and saved 161/1102 images
# Processing images:  15%|███                  | 162/1102 [00:23<02:15,  6.94it/s]
# Cropped and saved 162/1102 images
# Processing images:  15%|███                  | 163/1102 [00:23<02:14,  6.96it/s]
# Cropped and saved 163/1102 images
# Processing images:  15%|███▏                 | 164/1102 [00:23<02:16,  6.89it/s]
# Cropped and saved 164/1102 images
# Processing images:  15%|███▏                 | 165/1102 [00:24<02:15,  6.90it/s]
# Cropped and saved 165/1102 images
# Processing images:  15%|███▏                 | 166/1102 [00:24<02:16,  6.85it/s]
# Cropped and saved 166/1102 images
# Processing images:  15%|███▏                 | 167/1102 [00:24<02:15,  6.88it/s]
# Cropped and saved 167/1102 images
# Processing images:  15%|███▏                 | 168/1102 [00:24<02:15,  6.89it/s]
# Cropped and saved 168/1102 images
# Processing images:  15%|███▏                 | 169/1102 [00:24<02:16,  6.84it/s]
# Cropped and saved 169/1102 images
# Processing images:  15%|███▏                 | 170/1102 [00:24<02:16,  6.85it/s]
# Cropped and saved 170/1102 images
# Processing images:  16%|███▎                 | 171/1102 [00:24<02:15,  6.85it/s]
# Cropped and saved 171/1102 images
# Processing images:  16%|███▎                 | 172/1102 [00:25<02:16,  6.82it/s]
# Cropped and saved 172/1102 images
# Processing images:  16%|███▎                 | 173/1102 [00:25<02:15,  6.86it/s]
# Cropped and saved 173/1102 images
# Processing images:  16%|███▎                 | 174/1102 [00:25<02:15,  6.85it/s]
# Cropped and saved 174/1102 images
# Processing images:  16%|███▎                 | 175/1102 [00:25<02:14,  6.89it/s]
# Cropped and saved 175/1102 images
# Processing images:  16%|███▎                 | 176/1102 [00:25<02:14,  6.91it/s]
# Cropped and saved 176/1102 images
# Processing images:  16%|███▎                 | 177/1102 [00:25<02:14,  6.90it/s]
# Cropped and saved 177/1102 images
# Processing images:  16%|███▍                 | 178/1102 [00:26<02:14,  6.88it/s]
# Cropped and saved 178/1102 images
# Processing images:  16%|███▍                 | 179/1102 [00:26<02:14,  6.87it/s]
# Cropped and saved 179/1102 images
# Processing images:  16%|███▍                 | 180/1102 [00:26<02:13,  6.89it/s]
# Cropped and saved 180/1102 images
# Processing images:  16%|███▍                 | 181/1102 [00:26<02:13,  6.91it/s]
# Cropped and saved 181/1102 images
# Processing images:  17%|███▍                 | 182/1102 [00:26<02:13,  6.90it/s]
# Cropped and saved 182/1102 images
# Processing images:  17%|███▍                 | 183/1102 [00:26<02:12,  6.93it/s]
# Cropped and saved 183/1102 images
# Processing images:  17%|███▌                 | 184/1102 [00:26<02:12,  6.91it/s]
# Cropped and saved 184/1102 images
# Processing images:  17%|███▌                 | 185/1102 [00:27<02:11,  6.98it/s]
# Cropped and saved 185/1102 images
# Processing images:  17%|███▌                 | 186/1102 [00:27<02:11,  6.98it/s]
# Cropped and saved 186/1102 images
# Processing images:  17%|███▌                 | 187/1102 [00:27<02:10,  7.03it/s]
# Cropped and saved 187/1102 images
# Processing images:  17%|███▌                 | 188/1102 [00:27<02:09,  7.03it/s]
# Cropped and saved 188/1102 images
# Processing images:  17%|███▌                 | 189/1102 [00:27<02:10,  7.00it/s]
# Cropped and saved 189/1102 images
# Processing images:  17%|███▌                 | 190/1102 [00:27<02:10,  7.00it/s]
# Cropped and saved 190/1102 images
# Processing images:  17%|███▋                 | 191/1102 [00:27<02:09,  7.02it/s]
# Cropped and saved 191/1102 images
# Processing images:  17%|███▋                 | 192/1102 [00:28<02:10,  6.99it/s]
# Cropped and saved 192/1102 images
# Processing images:  18%|███▋                 | 193/1102 [00:28<02:09,  7.00it/s]
# Cropped and saved 193/1102 images
# Processing images:  18%|███▋                 | 194/1102 [00:28<02:09,  7.02it/s]
# Cropped and saved 194/1102 images
# Processing images:  18%|███▋                 | 195/1102 [00:28<02:10,  6.96it/s]
# Cropped and saved 195/1102 images
# Processing images:  18%|███▋                 | 196/1102 [00:28<02:09,  6.97it/s]
# Cropped and saved 196/1102 images
# Processing images:  18%|███▊                 | 197/1102 [00:28<02:15,  6.68it/s]
# Cropped and saved 197/1102 images
# Processing images:  18%|███▊                 | 198/1102 [00:28<02:18,  6.51it/s]
# Cropped and saved 198/1102 images
# Processing images:  18%|███▊                 | 199/1102 [00:29<02:18,  6.54it/s]
# Cropped and saved 199/1102 images
# Processing images:  18%|███▊                 | 200/1102 [00:29<02:14,  6.71it/s]
# Cropped and saved 200/1102 images
# Processing images:  18%|███▊                 | 201/1102 [00:29<02:13,  6.76it/s]
# Cropped and saved 201/1102 images
# Processing images:  18%|███▊                 | 202/1102 [00:29<02:13,  6.72it/s]
# Cropped and saved 202/1102 images
# Processing images:  18%|███▊                 | 203/1102 [00:29<02:12,  6.77it/s]
# Cropped and saved 203/1102 images
# Processing images:  19%|███▉                 | 204/1102 [00:29<02:12,  6.78it/s]
# Cropped and saved 204/1102 images
# Processing images:  19%|███▉                 | 205/1102 [00:29<02:10,  6.86it/s]
# Cropped and saved 205/1102 images
# Processing images:  19%|███▉                 | 206/1102 [00:30<02:11,  6.83it/s]
# Cropped and saved 206/1102 images
# Processing images:  19%|███▉                 | 207/1102 [00:30<02:10,  6.84it/s]
# Cropped and saved 207/1102 images
# Processing images:  19%|███▉                 | 208/1102 [00:30<02:11,  6.82it/s]
# Cropped and saved 208/1102 images
# Processing images:  19%|███▉                 | 209/1102 [00:30<02:10,  6.85it/s]
# Cropped and saved 209/1102 images
# Processing images:  19%|████                 | 210/1102 [00:30<02:09,  6.87it/s]
# Cropped and saved 210/1102 images
# Processing images:  19%|████                 | 211/1102 [00:30<02:09,  6.91it/s]
# Cropped and saved 211/1102 images
# Processing images:  19%|████                 | 212/1102 [00:30<02:08,  6.94it/s]
# Cropped and saved 212/1102 images
# Processing images:  19%|████                 | 213/1102 [00:31<02:08,  6.93it/s]
# Cropped and saved 213/1102 images
# Processing images:  19%|████                 | 214/1102 [00:31<02:08,  6.89it/s]
# Cropped and saved 214/1102 images
# Processing images:  20%|████                 | 215/1102 [00:31<02:09,  6.83it/s]
# Cropped and saved 215/1102 images
# Processing images:  20%|████                 | 216/1102 [00:31<02:09,  6.87it/s]
# Cropped and saved 216/1102 images
# Processing images:  20%|████▏                | 217/1102 [00:31<02:08,  6.90it/s]
# Cropped and saved 217/1102 images
# Processing images:  20%|████▏                | 218/1102 [00:31<02:09,  6.84it/s]
# Cropped and saved 218/1102 images
# Processing images:  20%|████▏                | 219/1102 [00:31<02:08,  6.90it/s]
# Cropped and saved 219/1102 images
# Processing images:  20%|████▏                | 220/1102 [00:32<02:07,  6.94it/s]
# Cropped and saved 220/1102 images
# Processing images:  20%|████▏                | 221/1102 [00:32<02:06,  6.95it/s]
# Cropped and saved 221/1102 images
# Processing images:  20%|████▏                | 222/1102 [00:32<02:06,  6.98it/s]
# Cropped and saved 222/1102 images
# Processing images:  20%|████▏                | 223/1102 [00:32<02:05,  6.99it/s]
# Cropped and saved 223/1102 images
# Processing images:  20%|████▎                | 224/1102 [00:32<02:05,  7.00it/s]
# Cropped and saved 224/1102 images
# Processing images:  20%|████▎                | 225/1102 [00:32<02:05,  6.99it/s]
# Cropped and saved 225/1102 images
# Processing images:  21%|████▎                | 226/1102 [00:32<02:05,  6.98it/s]
# Cropped and saved 226/1102 images
# Processing images:  21%|████▎                | 227/1102 [00:33<02:04,  7.01it/s]
# Cropped and saved 227/1102 images
# Processing images:  21%|████▎                | 228/1102 [00:33<02:04,  7.02it/s]
# Cropped and saved 228/1102 images
# Processing images:  21%|████▎                | 229/1102 [00:33<02:04,  7.01it/s]
# Cropped and saved 229/1102 images
# Processing images:  21%|████▍                | 230/1102 [00:33<02:04,  6.99it/s]
# Cropped and saved 230/1102 images
# Processing images:  21%|████▍                | 231/1102 [00:33<02:12,  6.59it/s]
# Cropped and saved 231/1102 images
# Processing images:  21%|████▍                | 233/1102 [00:34<02:27,  5.88it/s]
# Cropped and saved 232/1102 images
# Cropped and saved 233/1102 images
# Processing images:  21%|████▍                | 235/1102 [00:34<02:26,  5.94it/s]
# Cropped and saved 234/1102 images
# Cropped and saved 235/1102 images
# Processing images:  22%|████▌                | 237/1102 [00:34<02:24,  6.00it/s]
# Cropped and saved 236/1102 images
# Cropped and saved 237/1102 images
# Processing images:  22%|████▌                | 239/1102 [00:35<02:24,  5.98it/s]
# Cropped and saved 238/1102 images
# Cropped and saved 239/1102 images
# Processing images:  22%|████▌                | 241/1102 [00:35<02:23,  6.00it/s]
# Cropped and saved 240/1102 images
# Cropped and saved 241/1102 images
# Processing images:  22%|████▋                | 243/1102 [00:35<02:19,  6.14it/s]
# Cropped and saved 242/1102 images
# Cropped and saved 243/1102 images
# Processing images:  22%|████▋                | 245/1102 [00:36<02:19,  6.16it/s]
# Cropped and saved 244/1102 images
# Cropped and saved 245/1102 images
# Processing images:  22%|████▋                | 246/1102 [00:36<02:19,  6.15it/s]
# Cropped and saved 246/1102 images
# Processing images:  22%|████▋                | 247/1102 [00:36<02:40,  5.34it/s]
# Cropped and saved 247/1102 images
# Processing images:  23%|████▋                | 248/1102 [00:36<02:57,  4.81it/s]
# Cropped and saved 248/1102 images
# Processing images:  23%|████▋                | 249/1102 [00:37<03:12,  4.44it/s]
# Cropped and saved 249/1102 images
# Processing images:  23%|████▊                | 250/1102 [00:37<03:19,  4.27it/s]
# Cropped and saved 250/1102 images
# Processing images:  23%|████▊                | 251/1102 [00:37<03:39,  3.87it/s]
# Cropped and saved 251/1102 images
# Processing images:  23%|████▊                | 252/1102 [00:37<03:59,  3.54it/s]
# Cropped and saved 252/1102 images
# Processing images:  23%|████▊                | 254/1102 [00:38<03:36,  3.92it/s]
# Cropped and saved 253/1102 images
# Cropped and saved 254/1102 images
# Processing images:  23%|████▉                | 256/1102 [00:38<02:56,  4.78it/s]
# Cropped and saved 255/1102 images
# Cropped and saved 256/1102 images
# Processing images:  23%|████▉                | 258/1102 [00:39<02:40,  5.26it/s]
# Cropped and saved 257/1102 images
# Cropped and saved 258/1102 images
# Processing images:  24%|████▉                | 260/1102 [00:39<02:22,  5.90it/s]
# Cropped and saved 259/1102 images
# Cropped and saved 260/1102 images
# Processing images:  24%|████▉                | 262/1102 [00:39<02:12,  6.35it/s]
# Cropped and saved 261/1102 images
# Cropped and saved 262/1102 images
# Processing images:  24%|█████                | 264/1102 [00:39<02:07,  6.60it/s]
# Cropped and saved 263/1102 images
# Cropped and saved 264/1102 images
# Processing images:  24%|█████                | 266/1102 [00:40<02:03,  6.75it/s]
# Cropped and saved 265/1102 images
# Cropped and saved 266/1102 images
# Processing images:  24%|█████                | 268/1102 [00:40<02:01,  6.88it/s]
# Cropped and saved 267/1102 images
# Cropped and saved 268/1102 images
# Processing images:  25%|█████▏               | 270/1102 [00:40<02:00,  6.88it/s]
# Cropped and saved 269/1102 images
# Cropped and saved 270/1102 images
# Processing images:  25%|█████▏               | 272/1102 [00:41<02:00,  6.86it/s]
# Cropped and saved 271/1102 images
# Cropped and saved 272/1102 images
# Processing images:  25%|█████▏               | 274/1102 [00:41<02:00,  6.86it/s]
# Cropped and saved 273/1102 images
# Cropped and saved 274/1102 images
# Processing images:  25%|█████▎               | 276/1102 [00:41<01:59,  6.91it/s]
# Cropped and saved 275/1102 images
# Cropped and saved 276/1102 images
# Processing images:  25%|█████▎               | 278/1102 [00:41<01:59,  6.90it/s]
# Cropped and saved 277/1102 images
# Cropped and saved 278/1102 images
# Processing images:  25%|█████▎               | 280/1102 [00:42<01:58,  6.92it/s]
# Cropped and saved 279/1102 images
# Cropped and saved 280/1102 images
# Processing images:  26%|█████▎               | 282/1102 [00:42<01:58,  6.94it/s]
# Cropped and saved 281/1102 images
# Cropped and saved 282/1102 images
# Processing images:  26%|█████▍               | 284/1102 [00:42<01:58,  6.91it/s]
# Cropped and saved 283/1102 images
# Cropped and saved 284/1102 images
# Processing images:  26%|█████▍               | 286/1102 [00:43<01:56,  6.99it/s]
# Cropped and saved 285/1102 images
# Cropped and saved 286/1102 images
# Processing images:  26%|█████▍               | 288/1102 [00:43<01:56,  6.97it/s]
# Cropped and saved 287/1102 images
# Cropped and saved 288/1102 images
# Processing images:  26%|█████▌               | 290/1102 [00:43<01:56,  6.98it/s]
# Cropped and saved 289/1102 images
# Cropped and saved 290/1102 images
# Processing images:  26%|█████▌               | 292/1102 [00:43<01:55,  7.00it/s]
# Cropped and saved 291/1102 images
# Cropped and saved 292/1102 images
# Processing images:  27%|█████▌               | 294/1102 [00:44<01:55,  7.02it/s]
# Cropped and saved 293/1102 images
# Cropped and saved 294/1102 images
# Processing images:  27%|█████▋               | 296/1102 [00:44<02:00,  6.67it/s]
# Cropped and saved 295/1102 images
# Cropped and saved 296/1102 images
# Processing images:  27%|█████▋               | 298/1102 [00:44<01:58,  6.79it/s]
# Cropped and saved 297/1102 images
# Cropped and saved 298/1102 images
# Processing images:  27%|█████▋               | 300/1102 [00:45<01:58,  6.76it/s]
# Cropped and saved 299/1102 images
# Cropped and saved 300/1102 images
# Processing images:  27%|█████▊               | 302/1102 [00:45<01:58,  6.75it/s]
# Cropped and saved 301/1102 images
# Cropped and saved 302/1102 images
# Processing images:  28%|█████▊               | 304/1102 [00:45<01:57,  6.81it/s]
# Cropped and saved 303/1102 images
# Cropped and saved 304/1102 images
# Processing images:  28%|█████▊               | 306/1102 [00:46<01:55,  6.91it/s]
# Cropped and saved 305/1102 images
# Cropped and saved 306/1102 images
# Processing images:  28%|█████▊               | 308/1102 [00:46<01:54,  6.94it/s]
# Cropped and saved 307/1102 images
# Cropped and saved 308/1102 images
# Processing images:  28%|█████▉               | 310/1102 [00:46<01:54,  6.92it/s]
# Cropped and saved 309/1102 images
# Cropped and saved 310/1102 images
# Processing images:  28%|█████▉               | 312/1102 [00:46<01:54,  6.90it/s]
# Cropped and saved 311/1102 images
# Cropped and saved 312/1102 images
# Processing images:  28%|█████▉               | 314/1102 [00:47<01:55,  6.84it/s]
# Cropped and saved 313/1102 images
# Cropped and saved 314/1102 images
# Processing images:  29%|██████               | 316/1102 [00:47<01:56,  6.74it/s]
# Cropped and saved 315/1102 images
# Cropped and saved 316/1102 images
# Processing images:  29%|██████               | 318/1102 [00:47<01:54,  6.86it/s]
# Cropped and saved 317/1102 images
# Cropped and saved 318/1102 images
# Processing images:  29%|██████               | 320/1102 [00:48<01:55,  6.77it/s]
# Cropped and saved 319/1102 images
# Cropped and saved 320/1102 images
# Processing images:  29%|██████▏              | 322/1102 [00:48<01:53,  6.87it/s]
# Cropped and saved 321/1102 images
# Cropped and saved 322/1102 images
# Processing images:  29%|██████▏              | 324/1102 [00:48<01:52,  6.94it/s]
# Cropped and saved 323/1102 images
# Cropped and saved 324/1102 images
# Processing images:  30%|██████▏              | 326/1102 [00:48<01:51,  6.97it/s]
# Cropped and saved 325/1102 images
# Cropped and saved 326/1102 images
# Processing images:  30%|██████▎              | 328/1102 [00:49<01:50,  6.99it/s]
# Cropped and saved 327/1102 images
# Cropped and saved 328/1102 images
# Processing images:  30%|██████▎              | 330/1102 [00:49<01:50,  6.99it/s]
# Cropped and saved 329/1102 images
# Cropped and saved 330/1102 images
# Processing images:  30%|██████▎              | 332/1102 [00:49<01:50,  6.99it/s]
# Cropped and saved 331/1102 images
# Cropped and saved 332/1102 images
# Processing images:  30%|██████▎              | 334/1102 [00:50<01:50,  6.96it/s]
# Cropped and saved 333/1102 images
# Cropped and saved 334/1102 images
# Processing images:  30%|██████▍              | 336/1102 [00:50<01:49,  6.97it/s]
# Cropped and saved 335/1102 images
# Cropped and saved 336/1102 images
# Processing images:  31%|██████▍              | 338/1102 [00:50<01:49,  6.96it/s]
# Cropped and saved 337/1102 images
# Cropped and saved 338/1102 images
# Processing images:  31%|██████▍              | 340/1102 [00:50<01:49,  6.97it/s]
# Cropped and saved 339/1102 images
# Cropped and saved 340/1102 images
# Processing images:  31%|██████▌              | 342/1102 [00:51<01:49,  6.95it/s]
# Cropped and saved 341/1102 images
# Cropped and saved 342/1102 images
# Processing images:  31%|██████▌              | 344/1102 [00:51<01:49,  6.94it/s]
# Cropped and saved 343/1102 images
# Cropped and saved 344/1102 images
# Processing images:  31%|██████▌              | 346/1102 [00:51<01:49,  6.93it/s]
# Cropped and saved 345/1102 images
# Cropped and saved 346/1102 images
# Processing images:  32%|██████▋              | 348/1102 [00:52<01:48,  6.93it/s]
# Cropped and saved 347/1102 images
# Cropped and saved 348/1102 images
# Processing images:  32%|██████▋              | 350/1102 [00:52<01:48,  6.96it/s]
# Cropped and saved 349/1102 images
# Cropped and saved 350/1102 images
# Processing images:  32%|██████▋              | 352/1102 [00:52<01:48,  6.94it/s]
# Cropped and saved 351/1102 images
# Cropped and saved 352/1102 images
# Processing images:  32%|██████▋              | 354/1102 [00:52<01:47,  6.95it/s]
# Cropped and saved 353/1102 images
# Cropped and saved 354/1102 images
# Processing images:  32%|██████▊              | 356/1102 [00:53<01:46,  6.97it/s]
# Cropped and saved 355/1102 images
# Cropped and saved 356/1102 images
# Processing images:  32%|██████▊              | 358/1102 [00:53<01:46,  6.99it/s]
# Cropped and saved 357/1102 images
# Cropped and saved 358/1102 images
# Processing images:  33%|██████▊              | 360/1102 [00:53<01:45,  7.03it/s]
# Cropped and saved 359/1102 images
# Cropped and saved 360/1102 images
# Processing images:  33%|██████▉              | 362/1102 [00:54<01:45,  6.99it/s]
# Cropped and saved 361/1102 images
# Cropped and saved 362/1102 images
# Processing images:  33%|██████▉              | 364/1102 [00:54<01:45,  7.01it/s]
# Cropped and saved 363/1102 images
# Cropped and saved 364/1102 images
# Processing images:  33%|██████▉              | 366/1102 [00:54<01:44,  7.01it/s]
# Cropped and saved 365/1102 images
# Cropped and saved 366/1102 images
# Processing images:  33%|███████              | 368/1102 [00:54<01:45,  6.98it/s]
# Cropped and saved 367/1102 images
# Cropped and saved 368/1102 images
# Processing images:  34%|███████              | 370/1102 [00:55<01:45,  6.96it/s]
# Cropped and saved 369/1102 images
# Cropped and saved 370/1102 images
# Processing images:  34%|███████              | 372/1102 [00:55<01:44,  6.99it/s]
# Cropped and saved 371/1102 images
# Cropped and saved 372/1102 images
# Processing images:  34%|███████▏             | 374/1102 [00:55<01:46,  6.86it/s]
# Cropped and saved 373/1102 images
# Cropped and saved 374/1102 images
# Processing images:  34%|███████▏             | 376/1102 [00:56<01:44,  6.92it/s]
# Cropped and saved 375/1102 images
# Cropped and saved 376/1102 images
# Processing images:  34%|███████▏             | 378/1102 [00:56<01:44,  6.94it/s]
# Cropped and saved 377/1102 images
# Cropped and saved 378/1102 images
# Processing images:  34%|███████▏             | 380/1102 [00:56<01:43,  6.96it/s]
# Cropped and saved 379/1102 images
# Cropped and saved 380/1102 images
# Processing images:  35%|███████▎             | 382/1102 [00:56<01:42,  7.00it/s]
# Cropped and saved 381/1102 images
# Cropped and saved 382/1102 images
# Processing images:  35%|███████▎             | 384/1102 [00:57<01:43,  6.91it/s]
# Cropped and saved 383/1102 images
# Cropped and saved 384/1102 images
# Processing images:  35%|███████▎             | 386/1102 [00:57<01:43,  6.94it/s]
# Cropped and saved 385/1102 images
# Cropped and saved 386/1102 images
# Processing images:  35%|███████▍             | 388/1102 [00:57<01:42,  6.94it/s]
# Cropped and saved 387/1102 images
# Cropped and saved 388/1102 images
# Processing images:  35%|███████▍             | 390/1102 [00:58<01:44,  6.81it/s]
# Cropped and saved 389/1102 images
# Cropped and saved 390/1102 images
# Processing images:  36%|███████▍             | 392/1102 [00:58<01:44,  6.82it/s]
# Cropped and saved 391/1102 images
# Cropped and saved 392/1102 images
# Processing images:  36%|███████▌             | 394/1102 [00:58<01:42,  6.90it/s]
# Cropped and saved 393/1102 images
# Cropped and saved 394/1102 images
# Processing images:  36%|███████▌             | 396/1102 [00:59<01:41,  6.96it/s]
# Cropped and saved 395/1102 images
# Cropped and saved 396/1102 images
# Processing images:  36%|███████▌             | 398/1102 [00:59<01:40,  6.98it/s]
# Cropped and saved 397/1102 images
# Cropped and saved 398/1102 images
# Processing images:  36%|███████▌             | 400/1102 [00:59<01:40,  6.98it/s]
# Cropped and saved 399/1102 images
# Cropped and saved 400/1102 images
# Processing images:  36%|███████▋             | 402/1102 [00:59<01:40,  6.97it/s]
# Cropped and saved 401/1102 images
# Cropped and saved 402/1102 images
# Processing images:  37%|███████▋             | 404/1102 [01:00<01:46,  6.54it/s]
# Cropped and saved 403/1102 images
# Cropped and saved 404/1102 images
# Processing images:  37%|███████▋             | 406/1102 [01:00<01:44,  6.66it/s]
# Cropped and saved 405/1102 images
# Cropped and saved 406/1102 images
# Processing images:  37%|███████▊             | 408/1102 [01:00<01:41,  6.84it/s]
# Cropped and saved 407/1102 images
# Cropped and saved 408/1102 images
# Processing images:  37%|███████▊             | 410/1102 [01:01<01:40,  6.87it/s]
# Cropped and saved 409/1102 images
# Cropped and saved 410/1102 images
# Processing images:  37%|███████▊             | 412/1102 [01:01<01:40,  6.84it/s]
# Cropped and saved 411/1102 images
# Cropped and saved 412/1102 images
# Processing images:  38%|███████▉             | 414/1102 [01:01<01:40,  6.85it/s]
# Cropped and saved 413/1102 images
# Cropped and saved 414/1102 images
# Processing images:  38%|███████▉             | 416/1102 [01:01<01:39,  6.88it/s]
# Cropped and saved 415/1102 images
# Cropped and saved 416/1102 images
# Processing images:  38%|███████▉             | 418/1102 [01:02<01:38,  6.97it/s]
# Cropped and saved 417/1102 images
# Cropped and saved 418/1102 images
# Processing images:  38%|████████             | 420/1102 [01:02<01:37,  6.97it/s]
# Cropped and saved 419/1102 images
# Cropped and saved 420/1102 images
# Processing images:  38%|████████             | 422/1102 [01:02<01:37,  7.00it/s]
# Cropped and saved 421/1102 images
# Cropped and saved 422/1102 images
# Processing images:  38%|████████             | 424/1102 [01:03<01:37,  6.97it/s]
# Cropped and saved 423/1102 images
# Cropped and saved 424/1102 images
# Processing images:  39%|████████             | 426/1102 [01:03<01:38,  6.89it/s]
# Cropped and saved 425/1102 images
# Cropped and saved 426/1102 images
# Processing images:  39%|████████▏            | 428/1102 [01:03<01:37,  6.92it/s]
# Cropped and saved 427/1102 images
# Cropped and saved 428/1102 images
# Processing images:  39%|████████▏            | 430/1102 [01:03<01:37,  6.92it/s]
# Cropped and saved 429/1102 images
# Cropped and saved 430/1102 images
# Processing images:  39%|████████▏            | 432/1102 [01:04<01:36,  6.95it/s]
# Cropped and saved 431/1102 images
# Cropped and saved 432/1102 images
# Processing images:  39%|████████▎            | 434/1102 [01:04<01:36,  6.92it/s]
# Cropped and saved 433/1102 images
# Cropped and saved 434/1102 images
# Processing images:  40%|████████▎            | 436/1102 [01:04<01:36,  6.93it/s]
# Cropped and saved 435/1102 images
# Cropped and saved 436/1102 images
# Processing images:  40%|████████▎            | 438/1102 [01:05<01:35,  6.92it/s]
# Cropped and saved 437/1102 images
# Cropped and saved 438/1102 images
# Processing images:  40%|████████▍            | 440/1102 [01:05<01:35,  6.95it/s]
# Cropped and saved 439/1102 images
# Cropped and saved 440/1102 images
# Processing images:  40%|████████▍            | 442/1102 [01:05<01:34,  6.97it/s]
# Cropped and saved 441/1102 images
# Cropped and saved 442/1102 images
# Processing images:  40%|████████▍            | 444/1102 [01:05<01:35,  6.92it/s]
# Cropped and saved 443/1102 images
# Cropped and saved 444/1102 images
# Processing images:  40%|████████▍            | 446/1102 [01:06<01:35,  6.86it/s]
# Cropped and saved 445/1102 images
# Cropped and saved 446/1102 images
# Processing images:  41%|████████▌            | 448/1102 [01:06<01:35,  6.82it/s]
# Cropped and saved 447/1102 images
# Cropped and saved 448/1102 images
# Processing images:  41%|████████▌            | 450/1102 [01:06<01:35,  6.84it/s]
# Cropped and saved 449/1102 images
# Cropped and saved 450/1102 images
# Processing images:  41%|████████▌            | 452/1102 [01:07<01:34,  6.89it/s]
# Cropped and saved 451/1102 images
# Cropped and saved 452/1102 images
# Processing images:  41%|████████▋            | 454/1102 [01:07<01:33,  6.92it/s]
# Cropped and saved 453/1102 images
# Cropped and saved 454/1102 images
# Processing images:  41%|████████▋            | 456/1102 [01:07<01:33,  6.94it/s]
# Cropped and saved 455/1102 images
# Cropped and saved 456/1102 images
# Processing images:  42%|████████▋            | 458/1102 [01:08<01:33,  6.92it/s]
# Cropped and saved 457/1102 images
# Cropped and saved 458/1102 images
# Processing images:  42%|████████▊            | 460/1102 [01:08<01:33,  6.85it/s]
# Cropped and saved 459/1102 images
# Cropped and saved 460/1102 images
# Processing images:  42%|████████▊            | 462/1102 [01:08<01:32,  6.93it/s]
# Cropped and saved 461/1102 images
# Cropped and saved 462/1102 images
# Processing images:  42%|████████▊            | 464/1102 [01:08<01:31,  6.95it/s]
# Cropped and saved 463/1102 images
# Cropped and saved 464/1102 images
# Processing images:  42%|████████▉            | 466/1102 [01:09<01:30,  7.00it/s]
# Cropped and saved 465/1102 images
# Cropped and saved 466/1102 images
# Processing images:  42%|████████▉            | 468/1102 [01:09<01:30,  6.99it/s]
# Cropped and saved 467/1102 images
# Cropped and saved 468/1102 images
# Processing images:  43%|████████▉            | 470/1102 [01:09<01:33,  6.78it/s]
# Cropped and saved 469/1102 images
# Cropped and saved 470/1102 images
# Processing images:  43%|████████▉            | 472/1102 [01:10<01:32,  6.78it/s]
# Cropped and saved 471/1102 images
# Cropped and saved 472/1102 images
# Processing images:  43%|█████████            | 474/1102 [01:10<01:32,  6.81it/s]
# Cropped and saved 473/1102 images
# Cropped and saved 474/1102 images
# Processing images:  43%|█████████            | 476/1102 [01:10<01:31,  6.86it/s]
# Cropped and saved 475/1102 images
# Cropped and saved 476/1102 images
# Processing images:  43%|█████████            | 478/1102 [01:10<01:30,  6.89it/s]
# Cropped and saved 477/1102 images
# Cropped and saved 478/1102 images
# Processing images:  44%|█████████▏           | 480/1102 [01:11<01:29,  6.93it/s]
# Cropped and saved 479/1102 images
# Cropped and saved 480/1102 images
# Processing images:  44%|█████████▏           | 482/1102 [01:11<01:29,  6.92it/s]
# Cropped and saved 481/1102 images
# Cropped and saved 482/1102 images
# Processing images:  44%|█████████▏           | 484/1102 [01:11<01:29,  6.94it/s]
# Cropped and saved 483/1102 images
# Cropped and saved 484/1102 images
# Processing images:  44%|█████████▎           | 486/1102 [01:12<01:29,  6.91it/s]
# Cropped and saved 485/1102 images
# Cropped and saved 486/1102 images
# Processing images:  44%|█████████▎           | 488/1102 [01:12<01:29,  6.89it/s]
# Cropped and saved 487/1102 images
# Cropped and saved 488/1102 images
# Processing images:  44%|█████████▎           | 490/1102 [01:12<01:28,  6.90it/s]
# Cropped and saved 489/1102 images
# Cropped and saved 490/1102 images
# Processing images:  45%|█████████▍           | 492/1102 [01:12<01:27,  6.95it/s]
# Cropped and saved 491/1102 images
# Cropped and saved 492/1102 images
# Processing images:  45%|█████████▍           | 494/1102 [01:13<01:27,  6.97it/s]
# Cropped and saved 493/1102 images
# Cropped and saved 494/1102 images
# Processing images:  45%|█████████▍           | 496/1102 [01:13<01:27,  6.93it/s]
# Cropped and saved 495/1102 images
# Cropped and saved 496/1102 images
# Processing images:  45%|█████████▍           | 498/1102 [01:13<01:27,  6.94it/s]
# Cropped and saved 497/1102 images
# Cropped and saved 498/1102 images
# Processing images:  45%|█████████▌           | 500/1102 [01:14<01:26,  6.94it/s]
# Cropped and saved 499/1102 images
# Cropped and saved 500/1102 images
# Processing images:  46%|█████████▌           | 502/1102 [01:14<01:25,  6.98it/s]
# Cropped and saved 501/1102 images
# Cropped and saved 502/1102 images
# Processing images:  46%|█████████▌           | 504/1102 [01:14<01:25,  6.98it/s]
# Cropped and saved 503/1102 images
# Cropped and saved 504/1102 images
# Processing images:  46%|█████████▋           | 506/1102 [01:14<01:25,  7.00it/s]
# Cropped and saved 505/1102 images
# Cropped and saved 506/1102 images
# Processing images:  46%|█████████▋           | 508/1102 [01:15<01:25,  6.96it/s]
# Cropped and saved 507/1102 images
# Cropped and saved 508/1102 images
# Processing images:  46%|█████████▋           | 510/1102 [01:15<01:25,  6.96it/s]
# Cropped and saved 509/1102 images
# Cropped and saved 510/1102 images
# Processing images:  46%|█████████▊           | 512/1102 [01:15<01:24,  6.99it/s]
# Cropped and saved 511/1102 images
# Cropped and saved 512/1102 images
# ...
# Cropped and saved 890/1102 images
# Cropped and saved 891/1102 images
# Processing images:  81%|█████████████████    | 893/1102 [02:11<00:31,  6.69it/s]
# Cropped and saved 892/1102 images
# Cropped and saved 893/1102 images
# Processing images:  81%|█████████████████    | 895/1102 [02:12<00:30,  6.69it/s]
# Cropped and saved 894/1102 images
# Cropped and saved 895/1102 images
# Processing images:  81%|█████████████████    | 897/1102 [02:12<00:30,  6.71it/s]
# Cropped and saved 896/1102 images
# Cropped and saved 897/1102 images
# Processing images:  82%|█████████████████▏   | 899/1102 [02:12<00:30,  6.73it/s]
# Cropped and saved 898/1102 images
# Cropped and saved 899/1102 images
# Processing images:  82%|█████████████████▏   | 901/1102 [02:12<00:29,  6.72it/s]
# Cropped and saved 900/1102 images
# Cropped and saved 901/1102 images
# Processing images:  82%|█████████████████▏   | 903/1102 [02:13<00:29,  6.71it/s]
# Cropped and saved 902/1102 images
# Cropped and saved 903/1102 images
# Processing images:  82%|█████████████████▏   | 904/1102 [02:13<00:29,  6.62it/s]
# Cropped and saved 904/1102 images
# Processing images:  82%|█████████████████▎   | 906/1102 [02:13<00:33,  5.85it/s]
# Cropped and saved 905/1102 images
# Cropped and saved 906/1102 images
# Processing images:  82%|█████████████████▎   | 908/1102 [02:14<00:31,  6.18it/s]
# Cropped and saved 907/1102 images
# Cropped and saved 908/1102 images
# Processing images:  83%|█████████████████▎   | 910/1102 [02:14<00:30,  6.33it/s]
# Cropped and saved 909/1102 images
# Cropped and saved 910/1102 images
# Processing images:  83%|█████████████████▍   | 912/1102 [02:14<00:28,  6.56it/s]
# Cropped and saved 911/1102 images
# Cropped and saved 912/1102 images
# Processing images:  83%|█████████████████▍   | 914/1102 [02:14<00:28,  6.68it/s]
# Cropped and saved 913/1102 images
# Cropped and saved 914/1102 images
# Processing images:  83%|█████████████████▍   | 916/1102 [02:15<00:28,  6.59it/s]
# Cropped and saved 915/1102 images
# Cropped and saved 916/1102 images
# Processing images:  83%|█████████████████▍   | 918/1102 [02:15<00:27,  6.67it/s]
# Cropped and saved 917/1102 images
# Cropped and saved 918/1102 images
# Processing images:  83%|█████████████████▌   | 920/1102 [02:15<00:27,  6.73it/s]
# Cropped and saved 919/1102 images
# Cropped and saved 920/1102 images
# Processing images:  84%|█████████████████▌   | 922/1102 [02:16<00:26,  6.77it/s]
# Cropped and saved 921/1102 images
# Cropped and saved 922/1102 images
# Processing images:  84%|█████████████████▌   | 924/1102 [02:16<00:26,  6.81it/s]
# Cropped and saved 923/1102 images
# Cropped and saved 924/1102 images
# Processing images:  84%|█████████████████▋   | 926/1102 [02:16<00:25,  6.82it/s]
# Cropped and saved 925/1102 images
# Cropped and saved 926/1102 images
# Processing images:  84%|█████████████████▋   | 928/1102 [02:17<00:25,  6.84it/s]
# Cropped and saved 927/1102 images
# Cropped and saved 928/1102 images
# Processing images:  84%|█████████████████▋   | 930/1102 [02:17<00:25,  6.70it/s]
# Cropped and saved 929/1102 images
# Cropped and saved 930/1102 images
# Processing images:  85%|█████████████████▊   | 932/1102 [02:17<00:25,  6.79it/s]
# Cropped and saved 931/1102 images
# Cropped and saved 932/1102 images
# Processing images:  85%|█████████████████▊   | 934/1102 [02:17<00:24,  6.86it/s]
# Cropped and saved 933/1102 images
# Cropped and saved 934/1102 images
# Processing images:  85%|█████████████████▊   | 936/1102 [02:18<00:24,  6.86it/s]
# Cropped and saved 935/1102 images
# Cropped and saved 936/1102 images
# Processing images:  85%|█████████████████▊   | 938/1102 [02:18<00:23,  6.86it/s]
# Cropped and saved 937/1102 images
# Cropped and saved 938/1102 images
# Processing images:  85%|█████████████████▉   | 940/1102 [02:18<00:23,  6.86it/s]
# Cropped and saved 939/1102 images
# Cropped and saved 940/1102 images
# Processing images:  85%|█████████████████▉   | 942/1102 [02:19<00:23,  6.88it/s]
# Cropped and saved 941/1102 images
# Cropped and saved 942/1102 images
# Processing images:  86%|█████████████████▉   | 944/1102 [02:19<00:22,  6.89it/s]
# Cropped and saved 943/1102 images
# Cropped and saved 944/1102 images
# Processing images:  86%|██████████████████   | 946/1102 [02:19<00:22,  6.87it/s]
# Cropped and saved 945/1102 images
# Cropped and saved 946/1102 images
# Processing images:  86%|██████████████████   | 948/1102 [02:19<00:22,  6.86it/s]
# Cropped and saved 947/1102 images
# Cropped and saved 948/1102 images
# Processing images:  86%|██████████████████   | 950/1102 [02:20<00:22,  6.86it/s]
# Cropped and saved 949/1102 images
# Cropped and saved 950/1102 images
# Processing images:  86%|██████████████████▏  | 952/1102 [02:20<00:21,  6.86it/s]
# Cropped and saved 951/1102 images
# Cropped and saved 952/1102 images
# Processing images:  87%|██████████████████▏  | 954/1102 [02:20<00:21,  6.90it/s]
# Cropped and saved 953/1102 images
# Cropped and saved 954/1102 images
# Processing images:  87%|██████████████████▏  | 956/1102 [02:21<00:20,  6.96it/s]
# Cropped and saved 955/1102 images
# Cropped and saved 956/1102 images
# Processing images:  87%|██████████████████▎  | 958/1102 [02:21<00:20,  6.91it/s]
# Cropped and saved 957/1102 images
# Cropped and saved 958/1102 images
# Processing images:  87%|██████████████████▎  | 960/1102 [02:21<00:20,  6.93it/s]
# Cropped and saved 959/1102 images
# Cropped and saved 960/1102 images
# Processing images:  87%|██████████████████▎  | 962/1102 [02:22<00:20,  6.89it/s]
# Cropped and saved 961/1102 images
# Cropped and saved 962/1102 images
# Processing images:  87%|██████████████████▎  | 964/1102 [02:22<00:19,  6.92it/s]
# Cropped and saved 963/1102 images
# Cropped and saved 964/1102 images
# Processing images:  88%|██████████████████▍  | 966/1102 [02:22<00:19,  6.86it/s]
# Cropped and saved 965/1102 images
# Cropped and saved 966/1102 images
# Processing images:  88%|██████████████████▍  | 968/1102 [02:22<00:19,  6.75it/s]
# Cropped and saved 967/1102 images
# Cropped and saved 968/1102 images
# Processing images:  88%|██████████████████▍  | 970/1102 [02:23<00:19,  6.77it/s]
# Cropped and saved 969/1102 images
# Cropped and saved 970/1102 images
# Processing images:  88%|██████████████████▌  | 972/1102 [02:23<00:19,  6.72it/s]
# Cropped and saved 971/1102 images
# Cropped and saved 972/1102 images
# Processing images:  88%|██████████████████▌  | 974/1102 [02:23<00:18,  6.79it/s]
# Cropped and saved 973/1102 images
# Cropped and saved 974/1102 images
# Processing images:  89%|██████████████████▌  | 976/1102 [02:24<00:18,  6.83it/s]
# Cropped and saved 975/1102 images
# Cropped and saved 976/1102 images
# Processing images:  89%|██████████████████▋  | 978/1102 [02:24<00:18,  6.81it/s]
# Cropped and saved 977/1102 images
# Cropped and saved 978/1102 images
# Processing images:  89%|██████████████████▋  | 980/1102 [02:24<00:17,  6.82it/s]
# Cropped and saved 979/1102 images
# Cropped and saved 980/1102 images
# Processing images:  89%|██████████████████▋  | 982/1102 [02:24<00:17,  6.81it/s]
# Cropped and saved 981/1102 images
# Cropped and saved 982/1102 images
# Processing images:  89%|██████████████████▊  | 984/1102 [02:25<00:17,  6.75it/s]
# Cropped and saved 983/1102 images
# Cropped and saved 984/1102 images
# Processing images:  89%|██████████████████▊  | 986/1102 [02:25<00:16,  6.82it/s]
# Cropped and saved 985/1102 images
# Cropped and saved 986/1102 images
# Processing images:  90%|██████████████████▊  | 988/1102 [02:25<00:16,  6.88it/s]
# Cropped and saved 987/1102 images
# Cropped and saved 988/1102 images
# Processing images:  90%|██████████████████▊  | 990/1102 [02:26<00:16,  6.91it/s]
# Cropped and saved 989/1102 images
# Cropped and saved 990/1102 images
# Processing images:  90%|██████████████████▉  | 992/1102 [02:26<00:15,  6.91it/s]
# Cropped and saved 991/1102 images
# Cropped and saved 992/1102 images
# Processing images:  90%|██████████████████▉  | 994/1102 [02:26<00:15,  6.94it/s]
# Cropped and saved 993/1102 images
# Cropped and saved 994/1102 images
# Processing images:  90%|██████████████████▉  | 996/1102 [02:26<00:15,  6.92it/s]
# Cropped and saved 995/1102 images
# Cropped and saved 996/1102 images
# Processing images:  91%|███████████████████  | 998/1102 [02:27<00:14,  6.93it/s]
# Cropped and saved 997/1102 images
# Cropped and saved 998/1102 images
# Processing images:  91%|██████████████████▏ | 1000/1102 [02:27<00:14,  6.88it/s]
# Cropped and saved 999/1102 images
# Cropped and saved 1000/1102 images
# Processing images:  91%|██████████████████▏ | 1002/1102 [02:27<00:14,  6.91it/s]
# Cropped and saved 1001/1102 images
# Cropped and saved 1002/1102 images
# Processing images:  91%|██████████████████▏ | 1004/1102 [02:28<00:14,  6.91it/s]
# Cropped and saved 1003/1102 images
# Cropped and saved 1004/1102 images
# Processing images:  91%|██████████████████▎ | 1006/1102 [02:28<00:13,  6.91it/s]
# Cropped and saved 1005/1102 images
# Cropped and saved 1006/1102 images
# Processing images:  91%|██████████████████▎ | 1008/1102 [02:28<00:13,  6.90it/s]
# Cropped and saved 1007/1102 images
# Cropped and saved 1008/1102 images
# Processing images:  92%|██████████████████▎ | 1010/1102 [02:29<00:13,  6.90it/s]
# Cropped and saved 1009/1102 images
# Cropped and saved 1010/1102 images
# Processing images:  92%|██████████████████▎ | 1012/1102 [02:29<00:13,  6.92it/s]
# Cropped and saved 1011/1102 images
# Cropped and saved 1012/1102 images
# Processing images:  92%|██████████████████▍ | 1014/1102 [02:29<00:12,  6.91it/s]
# Cropped and saved 1013/1102 images
# Cropped and saved 1014/1102 images
# Processing images:  92%|██████████████████▍ | 1016/1102 [02:29<00:12,  6.71it/s]
# Cropped and saved 1015/1102 images
# Cropped and saved 1016/1102 images
# Processing images:  92%|██████████████████▍ | 1018/1102 [02:30<00:12,  6.77it/s]
# Cropped and saved 1017/1102 images
# Cropped and saved 1018/1102 images
# Processing images:  93%|██████████████████▌ | 1020/1102 [02:30<00:12,  6.77it/s]
# Cropped and saved 1019/1102 images
# Cropped and saved 1020/1102 images
# Processing images:  93%|██████████████████▌ | 1022/1102 [02:30<00:11,  6.80it/s]
# Cropped and saved 1021/1102 images
# Cropped and saved 1022/1102 images
# Processing images:  93%|██████████████████▌ | 1024/1102 [02:31<00:11,  6.69it/s]
# Cropped and saved 1023/1102 images
# Cropped and saved 1024/1102 images
# Processing images:  93%|██████████████████▌ | 1026/1102 [02:31<00:11,  6.84it/s]
# Cropped and saved 1025/1102 images
# Cropped and saved 1026/1102 images
# Processing images:  93%|██████████████████▋ | 1028/1102 [02:31<00:10,  6.87it/s]
# Cropped and saved 1027/1102 images
# Cropped and saved 1028/1102 images
# Processing images:  93%|██████████████████▋ | 1030/1102 [02:31<00:10,  6.87it/s]
# Cropped and saved 1029/1102 images
# Cropped and saved 1030/1102 images
# Processing images:  94%|██████████████████▋ | 1032/1102 [02:32<00:10,  6.87it/s]
# Cropped and saved 1031/1102 images
# Cropped and saved 1032/1102 images
# Processing images:  94%|██████████████████▊ | 1034/1102 [02:32<00:09,  6.85it/s]
# Cropped and saved 1033/1102 images
# Cropped and saved 1034/1102 images
# Processing images:  94%|██████████████████▊ | 1036/1102 [02:32<00:09,  6.83it/s]
# Cropped and saved 1035/1102 images
# Cropped and saved 1036/1102 images
# Processing images:  94%|██████████████████▊ | 1038/1102 [02:33<00:09,  6.87it/s]
# Cropped and saved 1037/1102 images
# Cropped and saved 1038/1102 images
# Processing images:  94%|██████████████████▊ | 1040/1102 [02:33<00:08,  6.90it/s]
# Cropped and saved 1039/1102 images
# Cropped and saved 1040/1102 images
# Processing images:  95%|██████████████████▉ | 1042/1102 [02:33<00:08,  6.85it/s]
# Cropped and saved 1041/1102 images
# Cropped and saved 1042/1102 images
# Processing images:  95%|██████████████████▉ | 1044/1102 [02:34<00:08,  6.55it/s]
# Cropped and saved 1043/1102 images
# Cropped and saved 1044/1102 images
# Processing images:  95%|██████████████████▉ | 1046/1102 [02:34<00:08,  6.62it/s]
# Cropped and saved 1045/1102 images
# Cropped and saved 1046/1102 images
# Processing images:  95%|███████████████████ | 1048/1102 [02:34<00:08,  6.73it/s]
# Cropped and saved 1047/1102 images
# Cropped and saved 1048/1102 images
# Processing images:  95%|███████████████████ | 1050/1102 [02:34<00:07,  6.78it/s]
# Cropped and saved 1049/1102 images
# Cropped and saved 1050/1102 images
# Processing images:  95%|███████████████████ | 1052/1102 [02:35<00:07,  6.83it/s]
# Cropped and saved 1051/1102 images
# Cropped and saved 1052/1102 images
# Processing images:  96%|███████████████████▏| 1054/1102 [02:35<00:06,  6.88it/s]
# Cropped and saved 1053/1102 images
# Cropped and saved 1054/1102 images
# Processing images:  96%|███████████████████▏| 1056/1102 [02:35<00:06,  6.86it/s]
# Cropped and saved 1055/1102 images
# Cropped and saved 1056/1102 images
# Processing images:  96%|███████████████████▏| 1058/1102 [02:36<00:06,  6.87it/s]
# Cropped and saved 1057/1102 images
# Cropped and saved 1058/1102 images
# Processing images:  96%|███████████████████▏| 1060/1102 [02:36<00:06,  6.89it/s]
# Cropped and saved 1059/1102 images
# Cropped and saved 1060/1102 images
# Processing images:  96%|███████████████████▎| 1062/1102 [02:36<00:05,  6.91it/s]
# Cropped and saved 1061/1102 images
# Cropped and saved 1062/1102 images
# Processing images:  97%|███████████████████▎| 1064/1102 [02:36<00:05,  6.92it/s]
# Cropped and saved 1063/1102 images
# Cropped and saved 1064/1102 images
# Processing images:  97%|███████████████████▎| 1066/1102 [02:37<00:05,  6.93it/s]
# Cropped and saved 1065/1102 images
# Cropped and saved 1066/1102 images
# Processing images:  97%|███████████████████▍| 1068/1102 [02:37<00:04,  6.85it/s]
# Cropped and saved 1067/1102 images
# Cropped and saved 1068/1102 images
# Processing images:  97%|███████████████████▍| 1070/1102 [02:37<00:04,  6.90it/s]
# Cropped and saved 1069/1102 images
# Cropped and saved 1070/1102 images
# Processing images:  97%|███████████████████▍| 1072/1102 [02:38<00:04,  6.96it/s]
# Cropped and saved 1071/1102 images
# Cropped and saved 1072/1102 images
# Processing images:  97%|███████████████████▍| 1074/1102 [02:38<00:04,  6.88it/s]
# Cropped and saved 1073/1102 images
# Cropped and saved 1074/1102 images
# Processing images:  98%|███████████████████▌| 1076/1102 [02:38<00:03,  6.87it/s]
# Cropped and saved 1075/1102 images
# Cropped and saved 1076/1102 images
# Processing images:  98%|███████████████████▌| 1078/1102 [02:38<00:03,  6.86it/s]
# Cropped and saved 1077/1102 images
# Cropped and saved 1078/1102 images
# Processing images:  98%|███████████████████▌| 1080/1102 [02:39<00:03,  6.79it/s]
# Cropped and saved 1079/1102 images
# Cropped and saved 1080/1102 images
# Processing images:  98%|███████████████████▋| 1082/1102 [02:39<00:02,  6.83it/s]
# Cropped and saved 1081/1102 images
# Cropped and saved 1082/1102 images
# Processing images:  98%|███████████████████▋| 1084/1102 [02:39<00:02,  6.87it/s]
# Cropped and saved 1083/1102 images
# Cropped and saved 1084/1102 images
# Processing images:  99%|███████████████████▋| 1086/1102 [02:40<00:02,  6.80it/s]
# Cropped and saved 1085/1102 images
# Cropped and saved 1086/1102 images
# Processing images:  99%|███████████████████▋| 1088/1102 [02:40<00:02,  6.74it/s]
# Cropped and saved 1087/1102 images
# Cropped and saved 1088/1102 images
# Processing images:  99%|███████████████████▊| 1090/1102 [02:40<00:01,  6.81it/s]
# Cropped and saved 1089/1102 images
# Cropped and saved 1090/1102 images
# Processing images:  99%|███████████████████▊| 1092/1102 [02:41<00:01,  6.85it/s]
# Cropped and saved 1091/1102 images
# Cropped and saved 1092/1102 images
# Processing images:  99%|███████████████████▊| 1094/1102 [02:41<00:01,  6.91it/s]
# Cropped and saved 1093/1102 images
# Cropped and saved 1094/1102 images
# Processing images:  99%|███████████████████▉| 1096/1102 [02:41<00:00,  6.88it/s]
# Cropped and saved 1095/1102 images
# Cropped and saved 1096/1102 images
# Processing images: 100%|███████████████████▉| 1098/1102 [02:41<00:00,  6.91it/s]
# Cropped and saved 1097/1102 images
# Cropped and saved 1098/1102 images
# Processing images: 100%|███████████████████▉| 1100/1102 [02:42<00:00,  6.88it/s]
# Cropped and saved 1099/1102 images
# Cropped and saved 1100/1102 images
# Processing images: 100%|████████████████████| 1102/1102 [02:42<00:00,  6.78it/s]
# Cropped and saved 1101/1102 images
# Cropped and saved 1102/1102 images
# Cropping process completed.
